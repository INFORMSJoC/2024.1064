# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from pwlopt.fitting.triangle import Triangle

# %%
pts = np.array([[0,0], [0,1], [1,0]])
pts = np.random.uniform(0,1, (3,2))
t = Triangle([0,1,2], pts)

# %%
r = .05
t.sample(r)
# Out:
# array([[0.30078929, 0.50237023],
#        [0.26701491, 0.77799226],
#        [0.27353934, 0.55344192],
#        [0.62339756, 0.46622115],
#        [0.31389334, 0.73727938],
#        [0.51119814, 0.69500379],
#        [0.6033264 , 0.33373066],
#        [0.75671593, 0.37360934],
#        [0.44495327, 0.69189822],
#        [0.39516075, 0.53914514],
#        [0.33599921, 0.58496818],
#        [0.47744418, 0.56437031],
#        [0.22375735, 0.54178758],
#        [0.2557522 , 0.41820066],
#        [0.53422504, 0.28875219],
#        [0.38067442, 0.32765295],
#        [0.61572799, 0.53980835],
#        [0.18682125, 0.37821856],
#        [0.44509561, 0.46032947],
#        [0.29584001, 0.68087262],
#        [0.40965265, 0.77583951],
#        [0.83526971, 0.22705517],
#        [0.2758243 , 0.83142568],
#        [0.44585475, 0.31496875],
#        [0.56033404, 0.6184153 ],
#        [0.24500896, 0.48733143],
#        [0.78500525, 0.24367413],
#        [0.68373696, 0.45877185],
# ...

# %%
t.plot_sample()
# Out:
# (<Figure size 1500x1000 with 1 Axes>, <Axes: >)

# %%
t.is_covered(r)
# Out:
# True
